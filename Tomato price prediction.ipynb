# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
# %matplotlib inline
import seaborn as sns

# %%
#import previous prices data
tomato = pd.read_csv('tomato_india.csv')
tomato
# Out:
#       Unnamed: 0    Datesk Item_Name        Date  Price
# 0            157  20110101    Tomoto    1/1/2011    NaN
# 1            525  20110102    Tomoto    2/1/2011    NaN
# 2            823  20110103    Tomoto    3/1/2011    NaN
# 3           1191  20110104    Tomoto    4/1/2011    NaN
# 4           1489  20110105    Tomoto    5/1/2011    NaN
# ...          ...       ...       ...         ...    ...
# 2608      867569  20180223    Tomoto  23/02/2018   10.0
# 2609      867896  20180224    Tomoto  24/02/2018   10.0
# 2610      868235  20180225    Tomoto  25/02/2018    NaN
# 2611      868561  20180226    Tomoto  26/02/2018   10.0
# 2612      868900  20180227    Tomoto  27/02/2018   10.0
#
# [2613 rows x 5 columns]

# %%
#drop unnecessary columns
tomato.drop('Unnamed: 0', axis=1)
# Out:
#         Datesk Item_Name        Date  Price
# 0     20110101    Tomoto    1/1/2011    NaN
# 1     20110102    Tomoto    2/1/2011    NaN
# 2     20110103    Tomoto    3/1/2011    NaN
# 3     20110104    Tomoto    4/1/2011    NaN
# 4     20110105    Tomoto    5/1/2011    NaN
# ...        ...       ...         ...    ...
# 2608  20180223    Tomoto  23/02/2018   10.0
# 2609  20180224    Tomoto  24/02/2018   10.0
# 2610  20180225    Tomoto  25/02/2018    NaN
# 2611  20180226    Tomoto  26/02/2018   10.0
# 2612  20180227    Tomoto  27/02/2018   10.0
#
# [2613 rows x 4 columns]

# %%
# Dates to datetime
tomato['Dates'] = pd.to_datetime(tomato['Date'])

# %%
tomato.isnull().sum()
# Out:
# Unnamed: 0      0
# Datesk          0
# Item_Name       0
# Date            0
# Price         566
# Dates           0
# dtype: int64

# %%
tomatodf = tomato.drop(['Unnamed: 0', 'Date'], axis=1)

# %%
tomatodf
# Out:
#         Datesk Item_Name  Price      Dates
# 0     20110101    Tomoto    NaN 2011-01-01
# 1     20110102    Tomoto    NaN 2011-02-01
# 2     20110103    Tomoto    NaN 2011-03-01
# 3     20110104    Tomoto    NaN 2011-04-01
# 4     20110105    Tomoto    NaN 2011-05-01
# ...        ...       ...    ...        ...
# 2608  20180223    Tomoto   10.0 2018-02-23
# 2609  20180224    Tomoto   10.0 2018-02-24
# 2610  20180225    Tomoto    NaN 2018-02-25
# 2611  20180226    Tomoto   10.0 2018-02-26
# 2612  20180227    Tomoto   10.0 2018-02-27
#
# [2613 rows x 4 columns]

# %%
tomatodf.drop(tomatodf.index[:102], inplace=True)

# %%
#fill na values witth farward fill method
tomatodf.fillna(method='ffill', inplace=True)

# %%
tomatodf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2511 entries, 102 to 2612
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Datesk     2511 non-null   int64
#  1   Item_Name  2511 non-null   object
#  2   Price      2511 non-null   float64
#  3   Dates      2511 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 98.1+ KB

# %%
tomatodf.fillna(value=10, inplace=True)

# %%
tomatodf.Datesk.astype(int)
# Out:
# 102     20110413
# 103     20110414
# 104     20110415
# 105     20110416
# 106     20110417
#           ...
# 2608    20180223
# 2609    20180224
# 2610    20180225
# 2611    20180226
# 2612    20180227
# Name: Datesk, Length: 2511, dtype: int32

# %%
# 2011 has a lot of null values so drop 2011 data
tomatodf.drop(tomatodf[tomatodf['Datesk'] < 20120000].index, inplace= True)

# %%
tomatodf.Item_Name.unique().tolist()
# Out:
# ['Tomoto']

# %%
tomatodf.drop(['Item_Name'], axis=1)
# Out:
#         Datesk  Price      Dates
# 365   20120101    6.0 2012-01-01
# 366   20120102    6.0 2012-02-01
# 367   20120103    6.0 2012-03-01
# 368   20120104    6.0 2012-04-01
# 369   20120105    6.0 2012-05-01
# ...        ...    ...        ...
# 2608  20180223   10.0 2018-02-23
# 2609  20180224   10.0 2018-02-24
# 2610  20180225   10.0 2018-02-25
# 2611  20180226   10.0 2018-02-26
# 2612  20180227   10.0 2018-02-27
#
# [2248 rows x 3 columns]

# %%
print(tomatodf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2248 entries, 365 to 2612
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Datesk     2248 non-null   int64
#  1   Item_Name  2248 non-null   object
#  2   Price      2248 non-null   float64
#  3   Dates      2248 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 87.8+ KB
# None

# %%
#there are no null values
tomatodf.isnull().sum()
# Out:
# Datesk       0
# Item_Name    0
# Price        0
# Dates        0
# dtype: int64

# %%
tomatodf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2248 entries, 365 to 2612
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Datesk     2248 non-null   int64
#  1   Item_Name  2248 non-null   object
#  2   Price      2248 non-null   float64
#  3   Dates      2248 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 87.8+ KB

# %%
#create columns for day, montth and year separate 
tomatodf['day'] = (tomatodf['Dates'].dt.day)
tomatodf['month'] = (tomatodf['Dates'].dt.month)
tomatodf['year'] = (tomatodf['Dates'].dt.year)


tomatodf
# Out:
#         Datesk Item_Name  Price      Dates  day  month  year
# 365   20120101    Tomoto    6.0 2012-01-01    1      1  2012
# 366   20120102    Tomoto    6.0 2012-02-01    1      2  2012
# 367   20120103    Tomoto    6.0 2012-03-01    1      3  2012
# 368   20120104    Tomoto    6.0 2012-04-01    1      4  2012
# 369   20120105    Tomoto    6.0 2012-05-01    1      5  2012
# ...        ...       ...    ...        ...  ...    ...   ...
# 2608  20180223    Tomoto   10.0 2018-02-23   23      2  2018
# 2609  20180224    Tomoto   10.0 2018-02-24   24      2  2018
# 2610  20180225    Tomoto   10.0 2018-02-25   25      2  2018
# 2611  20180226    Tomoto   10.0 2018-02-26   26      2  2018
# 2612  20180227    Tomoto   10.0 2018-02-27   27      2  2018
#
# [2248 rows x 7 columns]

# %%
#plot scatter plot for prices 
#extract a colum for only date and month
plt.scatter(tomatodf.Datesk, tomatodf.Price)
tomatodf['time'] = (tomatodf['Dates'].dt.strftime("%m-%d"))
tomatodf
# Out:
#         Datesk Item_Name  Price      Dates  day  month  year   time
# 365   20120101    Tomoto    6.0 2012-01-01    1      1  2012  01-01
# 366   20120102    Tomoto    6.0 2012-02-01    1      2  2012  02-01
# 367   20120103    Tomoto    6.0 2012-03-01    1      3  2012  03-01
# 368   20120104    Tomoto    6.0 2012-04-01    1      4  2012  04-01
# 369   20120105    Tomoto    6.0 2012-05-01    1      5  2012  05-01
# ...        ...       ...    ...        ...  ...    ...   ...    ...
# 2608  20180223    Tomoto   10.0 2018-02-23   23      2  2018  02-23
# 2609  20180224    Tomoto   10.0 2018-02-24   24      2  2018  02-24
# 2610  20180225    Tomoto   10.0 2018-02-25   25      2  2018  02-25
# 2611  20180226    Tomoto   10.0 2018-02-26   26      2  2018  02-26
# 2612  20180227    Tomoto   10.0 2018-02-27   27      2  2018  02-27
#
# [2248 rows x 8 columns]

# %%
#devide data into dataframes fof respective years
df2012 = tomatodf[(tomatodf['Datesk']>20120000)&(tomatodf['Datesk']<20130000)]
df2013 = tomatodf[(tomatodf['Datesk']>20130000)&(tomatodf['Datesk']<20140000)]
df2014 = tomatodf[(tomatodf['Datesk']>20140000)&(tomatodf['Datesk']<20150000)]
df2015 = tomatodf[(tomatodf['Datesk']>20150000)&(tomatodf['Datesk']<20160000)]
df2016 = tomatodf[(tomatodf['Datesk']>20160000)&(tomatodf['Datesk']<20170000)]
df2017 = tomatodf[(tomatodf['Datesk']>20170000)&(tomatodf['Datesk']<20180000)]
df2018 = tomatodf[(tomatodf['Datesk']>20180000)&(tomatodf['Datesk']<20190000)]

# %%
#plot a price plot to analyze price fluctuations
#lightcoral for even years green for odd years
plt.figure(figsize=(20,20))
plt.plot(df2012.index, df2012.Price, color='lightcoral', linewidth=4, linestyle=':')
plt.plot(df2013.index, df2013.Price, color='green', linewidth=4, linestyle=':')
plt.plot(df2014.index, df2014.Price, color='lightcoral', linewidth=4, linestyle=':')
plt.plot(df2015.index, df2015.Price, color='green', linewidth=4, linestyle=':')
plt.plot(df2016.index, df2016.Price, color='lightcoral', linewidth=4, linestyle=':')
plt.plot(df2017.index, df2017.Price, color='green', linewidth=4, linestyle=':')
plt.plot(df2018.index, df2018.Price, color='lightcoral', linewidth=4, linestyle=':')
plt.show()

# %%
#scatter a price scatter to analyze price fluctuations
#lightcoral for even years green for odd years
plt.figure(figsize=(20,20))
plt.scatter(df2012.index, df2012.Price, color='lightcoral', linewidth=4, linestyle='-')
plt.scatter(df2013.index, df2013.Price, color='green', linewidth=4, linestyle='-')
plt.scatter(df2014.index, df2014.Price, color='lightcoral', linewidth=4, linestyle=':')
plt.scatter(df2015.index, df2015.Price, color='green', linewidth=4, linestyle=':')
plt.scatter(df2016.index, df2016.Price, color='lightcoral', linewidth=4, linestyle='-')
plt.scatter(df2017.index, df2017.Price, color='green', linewidth=4, linestyle='-')
plt.scatter(df2018.index, df2018.Price, color='lightcoral', linewidth=4, linestyle='-')
plt.show()

# %%
df2015.set_index
# Out:
# <bound method DataFrame.set_index of         Datesk Item_Name  Price      Dates  day  month  year   time
# 1460  20150101    Tomoto   30.0 2015-01-01    1      1  2015  01-01
# 1461  20150102    Tomoto   31.0 2015-02-01    1      2  2015  02-01
# 1462  20150103    Tomoto   31.0 2015-03-01    1      3  2015  03-01
# 1463  20150104    Tomoto   31.0 2015-04-01    1      4  2015  04-01
# 1464  20150105    Tomoto   28.0 2015-05-01    1      5  2015  05-01
# ...        ...       ...    ...        ...  ...    ...   ...    ...
# 1820  20151227    Tomoto   32.0 2015-12-27   27     12  2015  12-27
# 1821  20151228    Tomoto   32.0 2015-12-28   28     12  2015  12-28
# 1822  20151229    Tomoto   38.0 2015-12-29   29     12  2015  12-29
# 1823  20151230    Tomoto   39.0 2015-12-30   30     12  2015  12-30
# 1824  20151231    Tomoto   39.0 2015-12-31   31     12  2015  12-31
#
# [365 rows x 8 columns]>

# %%
tomatodf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2248 entries, 365 to 2612
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Datesk     2248 non-null   int64
#  1   Item_Name  2248 non-null   object
#  2   Price      2248 non-null   float64
#  3   Dates      2248 non-null   datetime64[ns]
#  4   day        2248 non-null   int64
#  5   month      2248 non-null   int64
#  6   year       2248 non-null   int64
#  7   time       2248 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(2)
# memory usage: 158.1+ KB

# %%
df2015.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\toshiba\anaconda3\lib\site-packages\pandas\core\frame.py:4147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
df2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 1460 to 1824
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Datesk     365 non-null    int64
#  1   Item_Name  365 non-null    object
#  2   Price      365 non-null    float64
#  3   Dates      365 non-null    datetime64[ns]
#  4   day        365 non-null    int64
#  5   month      365 non-null    int64
#  6   year       365 non-null    int64
#  7   time       365 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(2)
# memory usage: 25.7+ KB

# %%
df2012['time'] = (df2012['Dates'].dt.strftime("%m-%d"))
# Out:
# <ipython-input-146-bd26a3fbfc59>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2012['time'] = (df2012['Dates'].dt.strftime("%m-%d"))

# %%
#integer location till 8th position 
df2012.iloc[:8]
# Out:
#        Datesk Item_Name  Price      Dates  day  month  year   time
# 365  20120101    Tomoto    6.0 2012-01-01    1      1  2012  01-01
# 366  20120102    Tomoto    6.0 2012-02-01    1      2  2012  02-01
# 367  20120103    Tomoto    6.0 2012-03-01    1      3  2012  03-01
# 368  20120104    Tomoto    6.0 2012-04-01    1      4  2012  04-01
# 369  20120105    Tomoto    6.0 2012-05-01    1      5  2012  05-01
# 370  20120106    Tomoto    6.0 2012-06-01    1      6  2012  06-01
# 371  20120107    Tomoto    6.0 2012-07-01    1      7  2012  07-01
# 372  20120108    Tomoto    6.0 2012-08-01    1      8  2012  08-01

# %%
#plot crosstab for month and date of different years
plt.figure(figsize=(20,20))
#plt.plot(df2012.time, df2012.Price)
plt.plot(df2012.time, df2012.Price, color='lightcoral', linewidth=4, linestyle='-')
plt.plot(df2013.time, df2013.Price, color='black', linewidth=4, linestyle=':')
plt.plot(df2014.time, df2014.Price, color='blue', linewidth=4, linestyle='-')
plt.plot(df2015.time, df2015.Price, color='green', linewidth=4, linestyle=':')
plt.plot(df2016.time, df2016.Price, color='orange', linewidth=4, linestyle='-.')
plt.plot(df2017.time, df2017.Price, color='red', linewidth=4, linestyle=':')
#plt.plot(df2018.time, df2018.Price, color='gray', linewidth=4, linestyle='--')
plt.show()

# %%
#plot scatter plot for month and date of different years
plt.figure(figsize=(20,20))
#plt.scatter(df2012.time, df2012.Price)
plt.scatter(df2012.time, df2012.Price, color='lightcoral', linewidth=4, linestyle='-')
plt.scatter(df2013.time, df2013.Price, color='black', linewidth=4, linestyle=':')
plt.scatter(df2014.time, df2014.Price, color='blue', linewidth=4, linestyle='-')
plt.scatter(df2015.time, df2015.Price, color='green', linewidth=4, linestyle=':')
plt.scatter(df2016.time, df2016.Price, color='orange', linewidth=4, linestyle='-.')
plt.scatter(df2017.time, df2017.Price, color='red', linewidth=4, linestyle=':')
#plt.scatter(df2018.time, df2018.Price, color='gray', linewidth=4, linestyle='--')
plt.show()

# %%
#2016 data
plt.figure(figsize=(20,20))
#plt.plot(df2018.time, df2018.Price, color='gray', linewidth=4, linestyle='--')
plt.plot(df2016.time, df2016.Price, color='lightcoral', linewidth=4, linestyle='-.')
print(df2016.shape)
# Out:
# (366, 8)

# %%
# Out:
# array([10., 12., 11.,  9.])

# %%
plt.figure(figsize=(20,20))
#plt.plot(df2012.month, df2012.Price)
#plt.plot(df2012.month, df2012.Price, color='lightcoral', linewidth=4, linestyle='-')
plt.scatter(df2013.month, df2013.Price, color='black', linewidth=4, linestyle=':')
#plt.plot(df2014.month, df2014.Price, color='blue', linewidth=4, linestyle='-')
#plt.plot(df2015.month, df2015.Price, color='green', linewidth=4, linestyle=':')
#plt.plot(df2016.month, df2016.Price, color='lightcoral', linewidth=4, linestyle='-.')
#plt.plot(df2017.month, df2017.Price, color='red', linewidth=4, linestyle=':')
#plt.plot(df2018.month, df2018.Price, color='gray', linewidth=4, linestyle='--')
plt.show()

# %%
plt.figure(figsize=(20,20))
#plt.plot(df2012.day, df2012.Price)
#plt.plot(df2012.day, df2012.Price, color='lightcoral', linewidth=4, linestyle='-')
plt.scatter(df2013.day, df2013.Price, color='black', linewidth=4, linestyle=':')
#plt.plot(df2014.day, df2014.Price, color='blue', linewidth=4, linestyle='-')
#plt.plot(df2015.day, df2015.Price, color='green', linewidth=4, linestyle=':')
#plt.plot(df2016.day, df2016.Price, color='lightcoral', linewidth=4, linestyle='-.')
#plt.plot(df2017.day, df2017.Price, color='red', linewidth=4, linestyle=':')
#plt.plot(df2018.day, df2018.Price, color='gray', linewidth=4, linestyle='--')
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(df2012.month, df2012.Price)
plt.scatter(df2012.month, df2012.Price, color='blue', linewidth=4, linestyle=':')
plt.scatter(df2013.month, df2013.Price, color='black', linewidth=4, linestyle=':')
plt.scatter(df2014.month, df2014.Price, color='blue', linewidth=4, linestyle='-')
plt.scatter(df2015.month, df2015.Price, color='green', linewidth=4, linestyle=':')
plt.scatter(df2016.month, df2016.Price, color='lightcoral', linewidth=4, linestyle='-.')
plt.scatter(df2017.month, df2017.Price, color='red', linewidth=4, linestyle=':')
plt.scatter(df2018.month, df2018.Price, color='gray', linewidth=4, linestyle='--')

plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df2013.x = df2013.time.apply(lambda x: x.split('-'))
# Out:
# <ipython-input-155-2aaca0290503>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df2013.x = df2013.time.apply(lambda x: x.split('-'))

# %%
df2013.describe()
# Out:
#              Datesk       Price         day       month    year
# count  3.650000e+02  365.000000  365.000000  365.000000   365.0
# mean   2.013067e+07   26.526027   15.720548    6.526027  2013.0
# std    3.454755e+02   14.064901    8.808321    3.452584     0.0
# min    2.013010e+07    8.000000    1.000000    1.000000  2013.0
# 25%    2.013040e+07   15.000000    8.000000    4.000000  2013.0
# 50%    2.013070e+07   23.000000   16.000000    7.000000  2013.0
# 75%    2.013100e+07   38.000000   23.000000   10.000000  2013.0
# max    2.013123e+07   60.000000   31.000000   12.000000  2013.0

# %%
df2014.describe()
# Out:
#              Datesk       Price         day       month    year
# count  3.640000e+02  364.000000  364.000000  364.000000   364.0
# mean   2.014067e+07   20.755495   15.760989    6.541209  2014.0
# std    3.446636e+02   14.771654    8.786448    3.445115     0.0
# min    2.014010e+07    6.000000    1.000000    1.000000  2014.0
# 25%    2.014040e+07   11.000000    8.000000    4.000000  2014.0
# 50%    2.014070e+07   16.000000   16.000000    7.000000  2014.0
# 75%    2.014100e+07   26.250000   23.000000   10.000000  2014.0
# max    2.014123e+07   70.000000   31.000000   12.000000  2014.0

# %%
df2015.describe()
# Out:
#              Datesk      Price         day       month    year
# count  3.650000e+02  365.00000  365.000000  365.000000   365.0
# mean   2.015067e+07   24.90137   15.720548    6.526027  2015.0
# std    3.454755e+02   11.09505    8.808321    3.452584     0.0
# min    2.015010e+07    9.00000    1.000000    1.000000  2015.0
# 25%    2.015040e+07   15.00000    8.000000    4.000000  2015.0
# 50%    2.015070e+07   24.00000   16.000000    7.000000  2015.0
# 75%    2.015100e+07   30.00000   23.000000   10.000000  2015.0
# max    2.015123e+07   64.00000   31.000000   12.000000  2015.0

# %%
df2016.describe()
# Out:
#              Datesk       Price         day       month    year
# count  3.660000e+02  366.000000  366.000000  366.000000   366.0
# mean   2.016067e+07   23.926230   15.756831    6.513661  2016.0
# std    3.457653e+02   18.109636    8.823592    3.455958     0.0
# min    2.016010e+07    8.000000    1.000000    1.000000  2016.0
# 25%    2.016040e+07   10.000000    8.000000    4.000000  2016.0
# 50%    2.016070e+07   17.000000   16.000000    7.000000  2016.0
# 75%    2.016098e+07   30.000000   23.000000    9.750000  2016.0
# max    2.016123e+07   82.000000   31.000000   12.000000  2016.0

# %%
df2017.describe()
# Out:
#              Datesk       Price         day       month    year
# count  3.640000e+02  364.000000  364.000000  364.000000   364.0
# mean   2.017067e+07   34.288462   15.760989    6.541209  2017.0
# std    3.446636e+02   20.322924    8.786448    3.445115     0.0
# min    2.017010e+07    9.000000    1.000000    1.000000  2017.0
# 25%    2.017040e+07   20.000000    8.000000    4.000000  2017.0
# 50%    2.017070e+07   28.000000   16.000000    7.000000  2017.0
# 75%    2.017100e+07   49.000000   23.000000   10.000000  2017.0
# max    2.017123e+07   92.000000   31.000000   12.000000  2017.0

# %%
df1 = tomatodf.reset_index()['Price']
df1.shape
# Out:
# (2248,)

# %%
plt.plot(df1)

# %%
#LSTM is sensitive to data
from  sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
df2 = scaler.fit_transform(np.array(df1).reshape(-1,1))
df2
# Out:
# array([[0.        ],
#        [0.        ],
#        [0.        ],
#        ...,
#        [0.04651163],
#        [0.04651163],
#        [0.04651163]])

# %%
train_size = int(len(df2)*0.75)
test_size = len(df2) - train_size
train_df, test_df = df2[0:train_size, :], df2[train_size:len(df2),:1]

# %%
train_size, test_size
# Out:
# (1686, 562)

# %%
def create_dataset(dataset, timestep=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-timestep-1):
        a = dataset[i:(i+timestep),0]
        dataX.append(a)
        dataY.append(dataset[i + timestep,0])
    return np.array(dataX), np.array(dataY)

# %%
timestep = 15
X_train, y_train = create_dataset(train_df, timestep)
X_test, y_test = create_dataset(test_df, timestep)

# %%
X_test.shape
# Out:
# (546, 15)

# %%
y_test.shape
# Out:
# (546,)

# %%
#reshape input to be  samples , timesteps, features which is required for LSTM 
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# create a stakled LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model = Sequential()
model.add(LSTM(50,return_sequences=True, input_shape=(15,1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer= 'adam')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_3 (LSTM)                (None, 15, 50)            10400
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 15, 50)            20200
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=30, batch_size=100, verbose= 1)
# Out:
# Epoch 1/30
# 17/17 [==============================] - 1s 41ms/step - loss: 7.1620e-04 - val_loss: 8.0943e-04
# Epoch 2/30
# 17/17 [==============================] - 1s 38ms/step - loss: 7.8768e-04 - val_loss: 9.1036e-04
# Epoch 3/30
# 17/17 [==============================] - 1s 39ms/step - loss: 7.1931e-04 - val_loss: 7.6511e-04
# Epoch 4/30
# 17/17 [==============================] - 1s 38ms/step - loss: 7.6447e-04 - val_loss: 8.7709e-04
# Epoch 5/30
# 17/17 [==============================] - 1s 38ms/step - loss: 7.5859e-04 - val_loss: 8.5023e-04
# Epoch 6/30
# 17/17 [==============================] - 1s 38ms/step - loss: 7.0963e-04 - val_loss: 0.0010
# Epoch 7/30
# 17/17 [==============================] - 1s 38ms/step - loss: 7.2567e-04 - val_loss: 7.7638e-04
# Epoch 8/30
# 17/17 [==============================] - 1s 39ms/step - loss: 7.2334e-04 - val_loss: 7.8064e-04
# Epoch 9/30
# 17/17 [==============================] - 1s 38ms/step - loss: 7.2173e-04 - val_loss: 9.2031e-04
# ...

# %%
# Lets do predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
#X_train = X_train[15:]
#X_train
#y_train = y_train[15:]
print(y_train.shape)
print(X_train.shape)
print(train_predict.shape)
# Out:
# (1670,)
# (1670, 15, 1)
# (1670, 1)

# %%
# Transform back to original format
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
#calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_test, test_predict))
# Out:
# 32.23614178431511

# %%
test_predict
# Out:
# array([[ 9.169765 ],
#        [ 9.171495 ],
#        [ 9.1735325],
#        [ 9.17549  ],
#        [ 9.17549  ],
#        [ 9.17549  ],
#        [ 9.17549  ],
#        [ 9.17549  ],
#        [ 9.17549  ],
#        [11.386436 ],
#        [12.324792 ],
#        [12.323085 ],
#        [12.122816 ],
#        [12.004993 ],
#        [11.978766 ],
#        [15.277407 ],
#        [16.412786 ],
#        [22.570662 ],
#        [23.937801 ],
#        [23.02326  ],
#        [17.364954 ],
#        [16.858852 ],
#        [17.576675 ],
#        [17.924984 ],
#        [16.995348 ],
#        [16.841635 ],
#        [16.892921 ],
#        [16.892235 ],
#        [16.857016 ],
#        [16.821177 ],
#        [17.791208 ],
#        [18.914112 ],
#        [18.934195 ],
#        [18.765041 ],
#        [22.807032 ],
#        [23.261635 ],
#        [28.132948 ],
#        [28.206032 ],
#        [27.438473 ],
#        [28.477598 ],
#        [27.395615 ],
#        [27.423119 ],
#        [27.612759 ],
# ...

# %%
math.sqrt(mean_squared_error(y_train, train_predict))
# Out:
# 26.842277991770317

# %%
# plotting of the predictions
plt.figure(figsize=(20,20))
look_back = 30
trainPredictPlot = np.empty_like(df2)
trainPredictPlot[:,:] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back,:] = train_predict
#shift test predictions for plotting
testPredictPlot = np.empty_like(df2)
testPredictPlot[:,:] = np.nan
testPredictPlot[len(train_predict)+(look_back)+1:len(df2)-1,:] = test_predict
# plot baseline and predictions
plt.scatter(df1.index, scaler.inverse_transform(df2))
plt.scatter(df1.index, trainPredictPlot, color='red')
plt.scatter(df1.index, testPredictPlot)
#plt.plot(df1)
plt.show()

# %%
import tensorflow as tf
testPredictPlot
# Out:
# array([[        nan],
#        [        nan],
#        [        nan],
#        ...,
#        [10.20478821],
#        [10.20947838],
#        [        nan]])

# %%
#predict the future 30 days
len(test_df)
562-15
# Out:
# 547

# %%
x_input = test_df[547:].reshape(1,-1)
x_input.shape
# Out:
# (1, 15)

# %%
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

# %%
temp_input
x_input
# Out:
# array([[0.04651163, 0.04651163, 0.03488372, 0.03488372, 0.03488372,
#         0.03488372, 0.03488372, 0.03488372, 0.03488372, 0.03488372,
#         0.04651163, 0.04651163, 0.04651163, 0.04651163, 0.04651163]])

# %%
df1.tail()
# Out:
# 2243    10.0
# 2244    10.0
# 2245    10.0
# 2246    10.0
# 2247    10.0
# Name: Price, dtype: float64

# %%
lst_output = []
n_steps = 15
i = 0
while(i<50):
    
    if(len(temp_input)>15):
        #print(temp_input)
        x_input = np.array(temp_input[1:])
        print("{} day input {} ".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1,n_steps, 1))
        #print (x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,scaler.inverse_transform(yhat)))
        temp_input = temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i = i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
# Out:
# [0.04785555]
# 16
# 0 day input [0.04651163 0.03488372 0.03488372 0.03488372 0.03488372 0.03488372
#  0.03488372 0.03488372 0.03488372 0.04651163 0.04651163 0.04651163
#  0.04651163 0.04651163 0.04785555]
# 0 day output [[10.193642]]
# [0.04876327]
# 16
# 1 day input [0.03488372 0.03488372 0.03488372 0.03488372 0.03488372 0.03488372
#  0.03488372 0.03488372 0.04651163 0.04651163 0.04651163 0.04651163
#  0.04651163 0.04785555 0.04876327]
# 1 day output [[10.29143]]
# [0.04990035]
# 16
# 2 day input [0.03488372 0.03488372 0.03488372 0.03488372 0.03488372 0.03488372
#  0.03488372 0.04651163 0.04651163 0.04651163 0.04651163 0.04651163
#  0.04785555 0.04876327 0.04990035]
# 2 day output [[10.394758]]
# [0.05110184]
# 16
# 3 day input [0.03488372 0.03488372 0.03488372 0.03488372 0.03488372 0.03488372
#  0.04651163 0.04651163 0.04651163 0.04651163 0.04651163 0.04785555
#  0.04876327 0.04990035 0.05110184]
# 3 day output [[10.500075]]
# [0.05232646]
# 16
# ...

# %%
df2018.head()
# Out:
#         Datesk Item_Name  Price      Dates  day  month  year   time
# 2555  20180101    Tomoto   10.0 2018-01-01    1      1  2018  01-01
# 2556  20180102    Tomoto   10.0 2018-02-01    1      2  2018  02-01
# 2557  20180103    Tomoto   10.0 2018-03-01    1      3  2018  03-01
# 2558  20180104    Tomoto   12.0 2018-04-01    1      4  2018  04-01
# 2559  20180105    Tomoto   11.0 2018-05-01    1      5  2018  05-01

# %%
day_next = np.arange(1, 50)
day_pred = np.arange(50, 100)

# %%
len(df1)
# Out:
# 2248

# %%
df3 = df2.tolist()
df3.extend(lst_output)

# %%
plt.plot(day_next, scaler.inverse_transform(df2[2199:]))
plt.plot(day_pred, scaler.inverse_transform(lst_output))

# %%
df2018.Price.unique()
# Out:
# array([10., 12., 11.,  9.])

# %% [markdown]
# #predicted prices for 2018 is between 10 and 12.5
# #Actual prices for first 58 days of 2018 is between 9 and 12

# %%
2248-49
# Out:
# 2199

# %%
df3 = df2.tolist()
df3.extend(lst_output)
plt.plot(df3[2000:])
